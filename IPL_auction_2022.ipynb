# %% [markdown]
# <a href="https://colab.research.google.com/github/Sainath1998/EXPLORATORY-DATA-ANALYSIS-USING-PYTHON/blob/main/IPL_auction_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px #importing plotly libraries

# %%
data_import=pd.read_csv("IPL_Auction_2022_FullList.csv")

# %%
data_import.head()
# Out:
#    Set No. Set Name          Player       Country State Association  Age  \
# 0        1        M     Trent Boult   New Zealand               NaN   32
# 1        1        M     Pat Cummins     Australia               NaN   28
# 2        1        M  Shikhar Dhawan         India              DDCA   36
# 3        1        M    Shreyas Iyer         India               MCA   27
# 4        1        M   Kagiso Rabada  South Africa               NaN   26
#
#     Specialism Batting               Bowling    IPL Previous IPLTeam(s)  \
# 0       BOWLER     RHB  LEFT ARM Fast Medium   62.0     SRH, KKR, DD,MI
# 1  ALL-ROUNDER     RHB        RIGHT ARM Fast   37.0         DD, MI, KKR
# 2      BATSMAN     LHB                     -  192.0    DCH, MI, SRH, DC
# 3      BATSMAN     RHB    RIGHT ARM Leg Spin   87.0                  DC
# 4       BOWLER     LHB        RIGHT ARM Fast   50.0                  DC
#
#   2021 Team   C/U/A  Base Price Sold Price          New Franchise   Bid
# ...

# %%
data_import.describe()
# Out:
#           Set No.         Age         IPL  Base Price
# count  589.000000  589.000000  270.000000  589.000000
# mean    32.096774   26.955857   29.425926   51.926995
# std     17.890516    4.690208   42.904494   53.467166
# min      1.000000   17.000000    0.000000   20.000000
# 25%     17.000000   23.000000    1.000000   20.000000
# 50%     32.000000   27.000000   10.500000   20.000000
# 75%     48.000000   30.000000   38.750000   50.000000
# max     62.000000   43.000000  213.000000  200.000000

# %%
data_import.dtypes
data_import.rename(columns={'New Franchise':'New_Franchise'},inplace = True)

# %%
nan_values = data_import.isna()
nan_columns = nan_values.any() #collums which have null values is true
nan_columns
# Out:
# Set No.                False
# Set Name               False
# Player                 False
# Country                False
# State Association       True
# Age                    False
# Specialism             False
# Batting                False
# Bowling                False
# IPL                     True
# Previous IPLTeam(s)     True
# 2021 Team               True
# C/U/A                  False
# Base Price             False
# Sold Price              True
# New_Franchise           True
# Bid                    False
# dtype: bool

# %%
youngsters = data_import.query('Age<20')
youngsters
# Out:
#      Set No. Set Name                  Player       Country State Association  \
# 45         7     UBA1           Dewald Brevis  South Africa               NaN
# 72        11     USP1              Noor Ahmad   Afghanistan               NaN
# 101       17     UAL2              Yash Dhull         India              DDCA
# 102       17     UAL2  Rajvardhan Hangargekar         India              MACA
# 105       17     UAL2            Vicky Ostwal         India              MACA
# 150       27     UFA3            Mayank Yadav         India              DDCA
# 161       33     UAL4        Aneeshwar Gautam         India              KSCA
# 182       54     UFA8            Ashok Sharma         India               RCA
# 224       16     UBA2           Harnoor Singh         India              UTCA
# 227       17     UAL2          Raj Angad Bawa         India              UTCA
# 228       17     UAL2          N. Tilak Varma         India              HYCA
# ...

# %%
experienced = data_import.query('Age>20')

# %% [markdown]
# #There no wicket keepers in youngsters

# %%
px.histogram(youngsters,x="Player",color="Specialism")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Too many bowlers and all rounders compared to other

# %%
px.histogram(experienced,x="Player",color="Specialism")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(experienced,x="Player",color="Specialism")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data_import.query('Country == "India"')
# Out:
#      Set No. Set Name               Player Country State Association  Age  \
# 2          1        M       Shikhar Dhawan   India              DDCA   36
# 3          1        M         Shreyas Iyer   India               MCA   27
# 5          1        M       Mohammad Shami   India               CAB   32
# 6          1        M            R. Ashwin   India              TNCA   35
# 12         2      BA1     Devdutt Padikkal   India              KSCA   21
# ..       ...      ...                  ...     ...               ...  ...
# 578       62    UAL15      Mohammed Afridi   India              HYCA   23
# 579       62    UAL15       Prerit Agrawal   India               VCA   20
# 582       62    UAL15    Nidhish Rajagopal   India              TNCA   22
# 583       62    UAL15     Bavanaka Sandeep   India              HYCA   29
# 586       62    UAL15  Maxwell Swaminathan   India               MCA   23
#
#       Specialism Batting                 Bowling    IPL Previous IPLTeam(s)  \
# ...

# %%
KKR = data_import.query('New_Franchise == "Kolkata Knight Riders"')
RR = data_import.query('New_Franchise == "Rajasthan Royals"')
PBKS = data_import.query('New_Franchise == "Punjab Kings"')
GT = data_import.query('New_Franchise == "Gujarat Titans"')
LSG = data_import.query('New_Franchise == "Lucknow Super Giants"')
RCB = data_import.query('New_Franchise == "Royal Challengers Bangalore"')
DC = data_import.query('New_Franchise == "Delhi Capitals"')
CSK = data_import.query('New_Franchise == "Chennai Super Kings"')
MI = data_import.query('New_Franchise == "Mumbai Indians"')
SRH = data_import.query('New_Franchise == "Sunrisers Hyderabad"')

# %%
px.histogram(KKR,x="Player",color="Specialism")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(MI,x="Player",color="Specialism")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(RR,x="Player",color="Specialism")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(PBKS,x="Player",color="Specialism")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(GT,x="Player",color="Specialism")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(RCB,x="Player",color="Specialism")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(CSK,x="Player",color="Specialism")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(LSG,x="Player",color="Specialism")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(SRH,x="Player",color="Specialism")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(DC,x="Player",color="Specialism")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#KKR = data_import.query('New_Franchise == "Kolkata Knight Riders"')
KKR.query('Age<25')
# Out:
#      Set No. Set Name        Player Country State Association  Age  \
# 56         8     UAL1   Shivam Mavi   India              UPCA   23
# 99        16     UBA2   Rinku Singh   India              UPCA   24
# 107       17     UAL2    Anukul Roy   India              JSCA   23
# 147       27     UFA3    Rasikh Dar   India              JKCA   22
# 172       47     UBA6  Ramesh Kumar   India               PCA   23
# 182       54     UFA8  Ashok Sharma   India               RCA   19
#
#       Specialism Batting                 Bowling   IPL Previous IPLTeam(s)  \
# 56   ALL-ROUNDER     RHB   RIGHT ARM Fast Medium  26.0                 KKR
# 99       BATSMAN     LHB      RIGHT ARM Off Spin  11.0                 KKR
# 107  ALL-ROUNDER     LHB  LEFT ARM Slow Orthodox   1.0                  MI
# 147       BOWLER     RHB   RIGHT ARM Fast Medium   1.0                  MI
# 172      BATSMAN     LHB                       -   NaN                 NaN
# ...

# %%
MI.query('Age<25')
# Out:
#      Set No. Set Name             Player       Country State Association  Age  \
# 27         4      WK1       Ishan Kishan         India              JSCA   23
# 45         7     UBA1      Dewald Brevis  South Africa               NaN   18
# 49         7     UBA1   Anmolpreet Singh         India               PCA   24
# 95        15      SP2    Mayank Markande         India               PCA   24
# 141       25     UAL3    Ramandeep Singh         India               PCA   24
# 143       26     UWK2        Aryan Juyal         India              UPCA   20
# 159       32     UBA4       Rahul Buddhi         India              HYCA   24
# 175       48     UAL6    Hrithik Shokeen         India              DDCA   21
# 183       57    UAL10    Arjun Tendulkar         India               MCA   22
# 228       17     UAL2     N. Tilak Varma         India              HYCA   19
# 500       53     UAL8  Mohd. Arshad Khan         India              MPCA   24
#
# ...
