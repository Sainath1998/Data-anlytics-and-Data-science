# %% [markdown]
# <a href="https://colab.research.google.com/github/Sainath1998/Netflix_EDA_Using-_python/blob/main/IPL_2022_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IPL EDA

# %%
import pandas as pd
import plotly.express as px

# %%
data_import = pd.read_csv("ipl_schedule.csv")
data_import
# Out:
#         DATE  TIME PM/AM                    HOME TEAM  \
# 0   26/03/22  7:30    PM          Chennai Super Kings
# 1   27/03/22  3:30    PM               Delhi Capitals
# 2   27/03/22  7:30    PM                 Punjab Kings
# 3   28/03/22  7:30    PM               Gujarat Titans
# 4   29/03/22  7:30    PM          Sunrisers Hyderabad
# ..       ...   ...   ...                          ...
# 65  18/05/22  7:30    PM        Kolkata Knight Riders
# 66  19/05/22  7:30    PM  Royal Challengers Bangalore
# 67  20/05/22  7:30    PM             Rajasthan Royals
# 68  21/05/22  7:30    PM               Mumbai Indians
# 69  22/05/22  7:30    PM          Sunrisers Hyderabad
#
#                       AWAY TEAM              VENUE
# 0         Kolkata Knight Riders   Wankhede Stadium
# 1                Mumbai Indians    Brabourne - CCI
# 2   Royal Challengers Bangalore   DY Patil Stadium
# 3          Lucknow Super Giants   Wankhede Stadium
# 4              Rajasthan Royals  MCA Stadium, Pune
# ...

# %%
data_import["DATE"]=pd.to_datetime(data_import["DATE"],format="%D/%M/%Y")
data_import["TIME"]=pd.to_datetime(data_import["TIME"],format="%H:%M")

# %%
data_import.dtypes
# Out:
# DATE         datetime64[ns]
# TIME         datetime64[ns]
# PM/AM                object
# HOME TEAM            object
# AWAY TEAM            object
# VENUE                object
# dtype: object

# %%
data_import["TIME"].hist()

# %%
px.histogram(data_import,x="TIME")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data_import_KKR = data_import[data_import["HOME TEAM"] == "Kolkata Knight Riders"]
data_import_KKR_away = data_import[data_import["AWAY TEAM"] == "Kolkata Knight Riders"]

# %%
data_import_KKR = pd.concat([data_import_KKR,data_import_KKR_away],axis = 1)

# %%
data_import_KKR
# Out:
#          DATE                TIME PM/AM              HOME TEAM  \
# 0         NaT                 NaT   NaN                    NaN
# 5         NaT                 NaT   NaN                    NaN
# 7  2022-01-04 1900-01-01 07:30:00    PM  Kolkata Knight Riders
# 13 2022-06-04 1900-01-01 07:30:00    PM  Kolkata Knight Riders
# 18 2022-10-04 1900-01-01 03:30:00    PM  Kolkata Knight Riders
# 24        NaT                 NaT   NaN                    NaN
# 29        NaT                 NaT   NaN                    NaN
# 34 2022-04-23 1900-01-01 03:30:00    PM  Kolkata Knight Riders
# 40        NaT                 NaT   NaN                    NaN
# 46 2022-02-05 1900-01-01 07:30:00    PM  Kolkata Knight Riders
# 52        NaT                 NaT   NaN                    NaN
# 55        NaT                 NaT   NaN                    NaN
# 60 2022-05-14 1900-01-01 07:30:00    PM  Kolkata Knight Riders
# 65 2022-05-18 1900-01-01 07:30:00    PM  Kolkata Knight Riders
#
# ...

# %%
data_import["VENUE"].unique()
#only 5 venues
# Out:
# array(['Wankhede Stadium', 'Brabourne - CCI', 'DY Patil Stadium',
#        'MCA Stadium, Pune'], dtype=object)

# %%
data_import["HOME TEAM"].unique()
# Out:
# array(['Chennai Super Kings', 'Delhi Capitals', 'Punjab Kings',
#        'Gujarat Titans', 'Sunrisers Hyderabad',
#        'Royal Challengers Bangalore', 'Lucknow Super Giants',
#        'Kolkata Knight Riders', 'Mumbai Indians', 'Rajasthan Royals'],
#       dtype=object)

# %%
ds = data_import[data_import["HOME TEAM"] == "Kolkata Knight Riders" ]
sd = data_import[data_import["AWAY TEAM"] == "Kolkata Knight Riders" ]

# %%
KKR  = pd.concat([ds,sd],axis = 1)

# %%
KKR
# Out:
#          DATE                TIME PM/AM              HOME TEAM  \
# 0         NaT                 NaT   NaN                    NaN
# 5         NaT                 NaT   NaN                    NaN
# 7  2022-01-04 1900-01-01 07:30:00    PM  Kolkata Knight Riders
# 13 2022-06-04 1900-01-01 07:30:00    PM  Kolkata Knight Riders
# 18 2022-10-04 1900-01-01 03:30:00    PM  Kolkata Knight Riders
# 24        NaT                 NaT   NaN                    NaN
# 29        NaT                 NaT   NaN                    NaN
# 34 2022-04-23 1900-01-01 03:30:00    PM  Kolkata Knight Riders
# 40        NaT                 NaT   NaN                    NaN
# 46 2022-02-05 1900-01-01 07:30:00    PM  Kolkata Knight Riders
# 52        NaT                 NaT   NaN                    NaN
# 55        NaT                 NaT   NaN                    NaN
# 60 2022-05-14 1900-01-01 07:30:00    PM  Kolkata Knight Riders
# 65 2022-05-18 1900-01-01 07:30:00    PM  Kolkata Knight Riders
#
# ...
